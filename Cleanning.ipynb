# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
# read and understand columns
i = 2015

while i != 2018:

    globals()[f'df{i}'] = pd.read_csv(f'{i}.csv')
    i += 1

while i != 2024:

    globals()[f'df{i}'] = pd.read_excel(f'{i}.xls')
    i+=1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f63ce884640b> in <module>
#       4 while i != 2018:
#       5
# ----> 6     globals()[f'df{i}'] = pd.read_csv(f'{i}.csv')
#       7     i += 1
#       8
#
# ...

# %%
df2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
df2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
df2018
# Out:
#                       Country  Happiness score  Whisker-high  Whisker-low  \
# 0                     Finland           7.6321      7.694913     7.569287
# 1                      Norway           7.5937      7.657077     7.530323
# 2                     Denmark           7.5553      7.623292     7.487309
# 3                     Iceland           7.4952      7.592534     7.397867
# 4                 Switzerland           7.4873      7.569994     7.404606
# ..                        ...              ...           ...          ...
# 152                  Tanzania           3.3035      3.413903     3.193097
# 153               South Sudan           3.2542      3.385097     3.123303
# 154  Central African Republic           3.0830      3.226582     2.939418
# 155                   Burundi           2.9045      3.074190     2.734810
# 156                       NaN              NaN           NaN          NaN
#
#      Dystopia (1.92) + residual  Explained by: GDP per capita  \
# ...

# %%
df2019
# Out:
#                       Country  Happiness score  Whisker-high  Whisker-low  \
# 0                     Finland           7.7689      7.829888     7.707912
# 1                     Denmark           7.6001      7.666658     7.533542
# 2                      Norway           7.5539      7.615639     7.492160
# 3                     Iceland           7.4936      7.613283     7.373917
# 4                 Netherlands           7.4876      7.542098     7.433102
# ..                        ...              ...           ...          ...
# 151                    Rwanda           3.3338      3.425188     3.242412
# 152                  Tanzania           3.2307      3.347133     3.114267
# 153               Afghanistan           3.2033      3.277512     3.129088
# 154  Central African Republic           3.0830      3.226582     2.939418
# 155               South Sudan           2.8526      3.004615     2.700585
#
#      Dystopia (1.88) + residual  Explained by: GDP per capita  \
# ...

# %%
df2020
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# ...

# %%
df2021
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe        7.8421
# 1        Denmark      Western Europe        7.6195
# 2    Switzerland      Western Europe        7.5715
# 3        Iceland      Western Europe        7.5539
# 4    Netherlands      Western Europe        7.4640
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa        3.5118
# 145     Botswana  Sub-Saharan Africa        3.4665
# 146       Rwanda  Sub-Saharan Africa        3.4147
# 147     Zimbabwe  Sub-Saharan Africa        3.1448
# 148  Afghanistan          South Asia        2.5229
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031646      7.904126      7.780075
# 1                          0.034657      7.687428      7.551572
# 2                          0.036243      7.642536      7.500463
# 3                          0.059373      7.670271      7.437528
# ...

# %%
df2022
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland           7.8210      7.886425     7.755575
# 1       2      Denmark           7.6362      7.709897     7.562503
# 2       3      Iceland           7.5575      7.651076     7.463924
# 3       4  Switzerland           7.5116      7.586394     7.436806
# 4       5  Netherlands           7.4149      7.471265     7.358534
# ..    ...          ...              ...           ...          ...
# 142   143      Rwanda*           3.2682      3.462218     3.074182
# 143   144     Zimbabwe           2.9951      3.109822     2.880378
# 144   145      Lebanon           2.9553      3.048951     2.861649
# 145   146  Afghanistan           2.4038      2.468731     2.338869
# 146   147           xx              NaN           NaN          NaN
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                      2.518052                      1.891628
# ...

# %%
df2023
# Out:
#          Country name  Ladder score  Standard error of ladder score  \
# 0             Finland        7.8042                        0.036162
# 1             Denmark        7.5864                        0.041028
# 2             Iceland        7.5296                        0.048612
# 3              Israel        7.4729                        0.031609
# 4         Netherlands        7.4030                        0.029294
# ..                ...           ...                             ...
# 132  Congo (Kinshasa)        3.2072                        0.095369
# 133          Zimbabwe        3.2035                        0.060865
# 134      Sierra Leone        3.1376                        0.082441
# 135           Lebanon        2.3922                        0.044495
# 136       Afghanistan        1.8590                        0.032506
#
#      upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 0        7.875078      7.733322              10.792010        0.968770
# ...

# %%
# data cleanning

df2015 = df2015.drop('Standard Error', axis=1)

# %%
df2016 = df2016.drop(['Lower Confidence Interval', 'Upper Confidence Interval'], axis=1)
df2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.526                   1.44178  1.16374
# 1              7.509                   1.52733  1.14524
# ...

# %%
columns = ['Country', 'Region', 'Happiness Rank', 'Happiness Score',	'Economy (GDP per Capita)',	'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

df2017 = df2017.drop(['Whisker.high','Whisker.low'],axis=1)

columns_mapping = {
    'Happiness.Rank' : 'Happiness Rank',
    'Happiness.Score' :'Happiness Score',
    'Economy..GDP.per.Capita.' : 'Economy (GDP per Capita)',
    'Family' : 'Family',
    'Health..Life.Expectancy.' : 'Health (Life Expectancy)',
    'Freedom' : "Freedom",
    'Generosity': 'Generosity',
    'Trust..Government.Corruption.' : 'Trust (Government Corruption)',
    'Dystopia.Residual' : 'Dystopia Residual'
    
}

df2017.rename(columns=columns_mapping, inplace=True)

merged_df = pd.merge(df2017, df2016[['Country', 'Region']], on='Country', how='left')

merged_df = merged_df[columns]

df2017 = merged_df

df2017
# Out:
#                       Country                           Region  \
# 0                      Norway                   Western Europe
# 1                     Denmark                   Western Europe
# 2                     Iceland                   Western Europe
# 3                 Switzerland                   Western Europe
# 4                     Finland                   Western Europe
# ..                        ...                              ...
# 150                    Rwanda               Sub-Saharan Africa
# 151                     Syria  Middle East and Northern Africa
# 152                  Tanzania               Sub-Saharan Africa
# 153                   Burundi               Sub-Saharan Africa
# 154  Central African Republic                              NaN
#
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)    Family  \
# 0                 1            7.537                  1.616463  1.533524
# ...

# %%
df2018_copy  = df2018

# %%
df2018_copy =df2018_copy.dropna(axis=1, how='all')
df2018_copy.dropna(axis=0, thresh=4, inplace=True)
df2018_copy
df2018_copy.drop(['Whisker-high', 'Whisker-low', 'Unnamed: 23'], axis=1, inplace=True)
df2018_copy
# Out:
# <ipython-input-154-4ab2d52c86b0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2018_copy.dropna(axis=0, thresh=4, inplace=True)
# <ipython-input-154-4ab2d52c86b0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2018_copy.drop(['Whisker-high', 'Whisker-low', 'Unnamed: 23'], axis=1, inplace=True)
#                       Country  Happiness score  Dystopia (1.92) + residual  \
# 0                     Finland           7.6321                    2.595186
# 1                      Norway           7.5937                    2.383242
# ...

# %%
columns_mapping = {
    'Happiness score' : 'Happiness Score',
    'Dystopia (1.92) + residual': 'Dystopia Residual',
    'Explained by: GDP per capita': 'Economy (GDP per Capita)',
    'Explained by: Social support': 'Family',
    'Explained by: Healthy life expectancy': 'Health (Life Expectancy)',
    'Explained by: Freedom to make life choices' : 'Freedom',
    'Explained by: Generosity': 'Generosity',
    'Explained by: Perceptions of corruption' : 'Trust (Government Corruption)'
}
df2018_copy.rename(columns=columns_mapping, inplace=True)
df2018_copy.insert(2, 'Happiness Rank', [None] * len(df2018_copy))
columns = ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',	'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

merged_df = pd.merge(df2018_copy, df2016[['Country', 'Region']], on='Country', how='left')

merged_df = merged_df[columns]


merged_df['Happiness Rank'] = range(1,157)


df2018 = merged_df
df2018
# Out:
# <ipython-input-155-092bd1e04676>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2018_copy.rename(columns=columns_mapping, inplace=True)
#                       Country                           Region  \
# 0                     Finland                   Western Europe
# 1                      Norway                   Western Europe
# 2                     Denmark                   Western Europe
# 3                     Iceland                   Western Europe
# 4                 Switzerland                   Western Europe
# ..                        ...                              ...
# 151                     Yemen  Middle East and Northern Africa
# 152                  Tanzania               Sub-Saharan Africa
# 153               South Sudan               Sub-Saharan Africa
# ...

# %%
df2019
# Out:
#                       Country  Happiness score  Whisker-high  Whisker-low  \
# 0                     Finland           7.7689      7.829888     7.707912
# 1                     Denmark           7.6001      7.666658     7.533542
# 2                      Norway           7.5539      7.615639     7.492160
# 3                     Iceland           7.4936      7.613283     7.373917
# 4                 Netherlands           7.4876      7.542098     7.433102
# ..                        ...              ...           ...          ...
# 151                    Rwanda           3.3338      3.425188     3.242412
# 152                  Tanzania           3.2307      3.347133     3.114267
# 153               Afghanistan           3.2033      3.277512     3.129088
# 154  Central African Republic           3.0830      3.226582     2.939418
# 155               South Sudan           2.8526      3.004615     2.700585
#
#      Dystopia (1.88) + residual  Explained by: GDP per capita  \
# ...

# %%
def clean(df):
    copy = df
    copy.drop(['Whisker-high', 'Whisker-low'], axis=1, inplace=True)
    columns_mapping = {
    'Happiness score' : 'Happiness Score',
    'Dystopia (1.88) + residual': 'Dystopia Residual',
    'Explained by: GDP per capita': 'Economy (GDP per Capita)',
    'Explained by: Social support': 'Family',
    'Explained by: Healthy life expectancy': 'Health (Life Expectancy)',
    'Explained by: Freedom to make life choices' : 'Freedom',
    'Explained by: Generosity': 'Generosity',
    'Explained by: Perceptions of corruption' : 'Trust (Government Corruption)'
}
    copy.rename(columns=columns_mapping, inplace=True)
    copy.insert(2, 'Happiness Rank', [None] * len(df2018_copy))
    columns = ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',	'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

    merged_df = pd.merge(copy, df2016[['Country', 'Region']], on='Country', how='left')

    merged_df = merged_df[columns]


    merged_df['Happiness Rank'] = range(1,157)


    df = merged_df

    return df

# %%
df2019 = clean(df2019)
df2019
# Out:
#                       Country              Region  Happiness Rank  \
# 0                     Finland      Western Europe               1
# 1                     Denmark      Western Europe               2
# 2                      Norway      Western Europe               3
# 3                     Iceland      Western Europe               4
# 4                 Netherlands      Western Europe               5
# ..                        ...                 ...             ...
# 151                    Rwanda  Sub-Saharan Africa             152
# 152                  Tanzania  Sub-Saharan Africa             153
# 153               Afghanistan       Southern Asia             154
# 154  Central African Republic                 NaN             155
# 155               South Sudan  Sub-Saharan Africa             156
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0             7.7689                  1.340243  1.587276
# ...

# %%
df2020
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# ...

# %%
df2020_copy = df2020

df2020_copy.drop(['Standard error of ladder score',	'upperwhisker',	'lowerwhisker',	'Logged GDP per capita', 'Social support',	'Healthy life expectancy',	'Freedom to make life choices',	'Generosity',	'Perceptions of corruption',	'Ladder score in Dystopia'], axis=1, inplace=True)

columns_mapping= { 
    'Country name': 'Country',
    'Regional indicator' : 'Region',
    'Ladder score': 'Happiness Score',
    'Explained by: Log GDP per capita': 'Economy (GDP per Capita)',
    'Explained by: Social support': 'Family',
    'Explained by: Healthy life expectancy': 'Health (Life Expectancy)',
    'Explained by: Freedom to make life choices' : 'Freedom',
    'Explained by: Generosity': 'Generosity',
    'Explained by: Perceptions of corruption' : 'Trust (Government Corruption)'
    
}

df2020_copy.rename(columns=columns_mapping, inplace=True)
df2020_copy.insert(2, 'Happiness Rank', [None] * len(df2020_copy))
df2020_copy['Happiness Rank'] = range(1, len(df2020_copy)+1)
df2020 = df2020_copy

# %%
df2021_copy = df2021

df2021_copy.drop(['Standard error of ladder score',	'upperwhisker',	'lowerwhisker',	'Logged GDP per capita', 'Social support',	'Healthy life expectancy',	'Freedom to make life choices',	'Generosity',	'Perceptions of corruption',	'Ladder score in Dystopia'], axis=1, inplace=True)
columns_mapping= { 
    'Country name': 'Country',
    'Regional indicator' : 'Region',
    'Ladder score': 'Happiness Score',
    'Explained by: Log GDP per capita': 'Economy (GDP per Capita)',
    'Explained by: Social support': 'Family',
    'Explained by: Healthy life expectancy': 'Health (Life Expectancy)',
    'Explained by: Freedom to make life choices' : 'Freedom',
    'Explained by: Generosity': 'Generosity',
    'Explained by: Perceptions of corruption' : 'Trust (Government Corruption)'
}
df2021_copy.rename(columns=columns_mapping, inplace=True)
df2021_copy.insert(2, 'Happiness Rank', [None] * len(df2021_copy))
df2021_copy['Happiness Rank'] = range(1, len(df2021_copy)+1)
df2021 = df2021_copy
df2021
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0        Finland      Western Europe               1           7.8421
# 1        Denmark      Western Europe               2           7.6195
# 2    Switzerland      Western Europe               3           7.5715
# 3        Iceland      Western Europe               4           7.5539
# 4    Netherlands      Western Europe               5           7.4640
# ..           ...                 ...             ...              ...
# 144      Lesotho  Sub-Saharan Africa             145           3.5118
# 145     Botswana  Sub-Saharan Africa             146           3.4665
# 146       Rwanda  Sub-Saharan Africa             147           3.4147
# 147     Zimbabwe  Sub-Saharan Africa             148           3.1448
# 148  Afghanistan          South Asia             149           2.5229
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# ...

# %%
df2022
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland           7.8210      7.886425     7.755575
# 1       2      Denmark           7.6362      7.709897     7.562503
# 2       3      Iceland           7.5575      7.651076     7.463924
# 3       4  Switzerland           7.5116      7.586394     7.436806
# 4       5  Netherlands           7.4149      7.471265     7.358534
# ..    ...          ...              ...           ...          ...
# 142   143      Rwanda*           3.2682      3.462218     3.074182
# 143   144     Zimbabwe           2.9951      3.109822     2.880378
# 144   145      Lebanon           2.9553      3.048951     2.861649
# 145   146  Afghanistan           2.4038      2.468731     2.338869
# 146   147           xx              NaN           NaN          NaN
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                      2.518052                      1.891628
# ...

# %%
df2022_copy = df2022

df2022_copy.drop(['Whisker-high', 'Whisker-low'], axis=1, inplace = True)
columns_mapping= {
    'RANK' : 'Happiness Rank',
    'Happiness score' : 'Happiness Score',
    'Dystopia (1.83) + residual': 'Dystopia Residual',
    'Explained by: GDP per capita': 'Economy (GDP per Capita)',
    'Explained by: Social support': 'Family',
    'Explained by: Healthy life expectancy': 'Health (Life Expectancy)',
    'Explained by: Freedom to make life choices' : 'Freedom',
    'Explained by: Generosity': 'Generosity',
    'Explained by: Perceptions of corruption' : 'Trust (Government Corruption)'
}


columns = ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',	'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

df2022_copy.rename(columns=columns_mapping, inplace=True)

merged_df = pd.merge(df2022_copy, df2016[['Country', 'Region']], on='Country', how='left')

merged_df = merged_df[columns]
df2022_copy = merged_df[columns]
df2022_copy.drop(df2022_copy.index[-1], inplace=True)
df2022_copy
df2022 = df2022_copy

# %%
df2023
# Out:
#          Country name  Ladder score  Standard error of ladder score  \
# 0             Finland        7.8042                        0.036162
# 1             Denmark        7.5864                        0.041028
# 2             Iceland        7.5296                        0.048612
# 3              Israel        7.4729                        0.031609
# 4         Netherlands        7.4030                        0.029294
# ..                ...           ...                             ...
# 132  Congo (Kinshasa)        3.2072                        0.095369
# 133          Zimbabwe        3.2035                        0.060865
# 134      Sierra Leone        3.1376                        0.082441
# 135           Lebanon        2.3922                        0.044495
# 136       Afghanistan        1.8590                        0.032506
#
#      upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 0        7.875078      7.733322              10.792010        0.968770
# ...

# %%
df2023_copy = df2023

df2023_copy.drop(['Standard error of ladder score',	'upperwhisker',	'lowerwhisker',	'Logged GDP per capita', 'Social support',	'Healthy life expectancy',	'Freedom to make life choices',	'Generosity',	'Perceptions of corruption',	'Ladder score in Dystopia'], axis=1, inplace = True)
columns_mapping= { 
    'Country name': 'Country',
    'Regional indicator' : 'Region',
    'Ladder score': 'Happiness Score',
    'Explained by: Log GDP per capita': 'Economy (GDP per Capita)',
    'Explained by: Social support': 'Family',
    'Explained by: Healthy life expectancy': 'Health (Life Expectancy)',
    'Explained by: Freedom to make life choices' : 'Freedom',
    'Explained by: Generosity': 'Generosity',
    'Explained by: Perceptions of corruption' : 'Trust (Government Corruption)',
    'Dystopia + residual' : 'Dystopia Residual'
}
df2023_copy.rename(columns=columns_mapping, inplace=True)
df2023_copy.insert(2, 'Happiness Rank', [None] * len(df2023_copy))
df2023_copy['Happiness Rank'] = range(1, len(df2023_copy)+1)
merged_df = pd.merge(df2023_copy, df2016[['Country', 'Region']], on='Country', how='left')
columns = ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',	'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']
merged_df = merged_df[columns]

df2023 = merged_df
df2023
# Out:
#               Country                           Region  Happiness Rank  \
# 0             Finland                   Western Europe               1
# 1             Denmark                   Western Europe               2
# 2             Iceland                   Western Europe               3
# 3              Israel  Middle East and Northern Africa               4
# 4         Netherlands                   Western Europe               5
# ..                ...                              ...             ...
# 132  Congo (Kinshasa)               Sub-Saharan Africa             133
# 133          Zimbabwe               Sub-Saharan Africa             134
# 134      Sierra Leone               Sub-Saharan Africa             135
# 135           Lebanon  Middle East and Northern Africa             136
# 136       Afghanistan                    Southern Asia             137
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# ...

# %%
df2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# ...

# %%
df2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.526                   1.44178  1.16374
# 1              7.509                   1.52733  1.14524
# ...

# %%
df2017
# Out:
#                       Country                           Region  \
# 0                      Norway                   Western Europe
# 1                     Denmark                   Western Europe
# 2                     Iceland                   Western Europe
# 3                 Switzerland                   Western Europe
# 4                     Finland                   Western Europe
# ..                        ...                              ...
# 150                    Rwanda               Sub-Saharan Africa
# 151                     Syria  Middle East and Northern Africa
# 152                  Tanzania               Sub-Saharan Africa
# 153                   Burundi               Sub-Saharan Africa
# 154  Central African Republic                              NaN
#
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)    Family  \
# 0                 1            7.537                  1.616463  1.533524
# ...

# %%
df2018
# Out:
#                       Country                           Region  \
# 0                     Finland                   Western Europe
# 1                      Norway                   Western Europe
# 2                     Denmark                   Western Europe
# 3                     Iceland                   Western Europe
# 4                 Switzerland                   Western Europe
# ..                        ...                              ...
# 151                     Yemen  Middle East and Northern Africa
# 152                  Tanzania               Sub-Saharan Africa
# 153               South Sudan               Sub-Saharan Africa
# 154  Central African Republic                              NaN
# 155                   Burundi               Sub-Saharan Africa
#
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)    Family  \
# 0                 1           7.6321                  1.305095  1.592134
# ...

# %%
df2019
# Out:
#                       Country              Region  Happiness Rank  \
# 0                     Finland      Western Europe               1
# 1                     Denmark      Western Europe               2
# 2                      Norway      Western Europe               3
# 3                     Iceland      Western Europe               4
# 4                 Netherlands      Western Europe               5
# ..                        ...                 ...             ...
# 151                    Rwanda  Sub-Saharan Africa             152
# 152                  Tanzania  Sub-Saharan Africa             153
# 153               Afghanistan       Southern Asia             154
# 154  Central African Republic                 NaN             155
# 155               South Sudan  Sub-Saharan Africa             156
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0             7.7689                  1.340243  1.587276
# ...

# %%
df2020
# Out:
#                       Country              Region  Happiness Rank  \
# 0                     Finland      Western Europe               1
# 1                     Denmark      Western Europe               2
# 2                 Switzerland      Western Europe               3
# 3                     Iceland      Western Europe               4
# 4                      Norway      Western Europe               5
# ..                        ...                 ...             ...
# 148  Central African Republic  Sub-Saharan Africa             149
# 149                    Rwanda  Sub-Saharan Africa             150
# 150                  Zimbabwe  Sub-Saharan Africa             151
# 151               South Sudan  Sub-Saharan Africa             152
# 152               Afghanistan          South Asia             153
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0             7.8087                  1.285190  1.499526
# ...

# %%
df2021
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0        Finland      Western Europe               1           7.8421
# 1        Denmark      Western Europe               2           7.6195
# 2    Switzerland      Western Europe               3           7.5715
# 3        Iceland      Western Europe               4           7.5539
# 4    Netherlands      Western Europe               5           7.4640
# ..           ...                 ...             ...              ...
# 144      Lesotho  Sub-Saharan Africa             145           3.5118
# 145     Botswana  Sub-Saharan Africa             146           3.4665
# 146       Rwanda  Sub-Saharan Africa             147           3.4147
# 147     Zimbabwe  Sub-Saharan Africa             148           3.1448
# 148  Afghanistan          South Asia             149           2.5229
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# ...

# %%
df2022
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Finland                   Western Europe               1
# 1        Denmark                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3    Switzerland                   Western Europe               4
# 4    Netherlands                   Western Europe               5
# ..           ...                              ...             ...
# 141    Botswana*                              NaN             142
# 142      Rwanda*                              NaN             143
# 143     Zimbabwe               Sub-Saharan Africa             144
# 144      Lebanon  Middle East and Northern Africa             145
# 145  Afghanistan                    Southern Asia             146
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0             7.8210                  1.891628  1.258108
# ...

# %%
df2023
# Out:
#               Country                           Region  Happiness Rank  \
# 0             Finland                   Western Europe               1
# 1             Denmark                   Western Europe               2
# 2             Iceland                   Western Europe               3
# 3              Israel  Middle East and Northern Africa               4
# 4         Netherlands                   Western Europe               5
# ..                ...                              ...             ...
# 132  Congo (Kinshasa)               Sub-Saharan Africa             133
# 133          Zimbabwe               Sub-Saharan Africa             134
# 134      Sierra Leone               Sub-Saharan Africa             135
# 135           Lebanon  Middle East and Northern Africa             136
# 136       Afghanistan                    Southern Asia             137
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# ...

# %%
df2023[df2023.isna().any(axis=1)]
# Out:
#                        Country Region  Happiness Rank  Happiness Score  \
# 17                     Czechia    NaN              18           6.8452
# 26    Taiwan Province of China    NaN              27           6.5354
# 81   Hong Kong S.A.R. of China    NaN              82           5.3085
# 86             North Macedonia    NaN              87           5.2536
# 96                  Mozambique    NaN              97           4.9540
# 98          State of Palestine    NaN              99           4.9078
# 105                    Turkiye    NaN             106           4.6135
# 118                     Gambia    NaN             119           4.2794
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 17                   1.823469  1.543999                  0.477349  0.693139
# 26                   1.890335  1.371842                  0.492341  0.561938
# 81                   1.950940  1.201336                  0.701590  0.406797
# ...

# %%
df2022[df2022.isna().any(axis=1)]
# Out:
#                        Country Region  Happiness Rank  Happiness Score  \
# 5                  Luxembourg*    NaN               6           7.4040
# 17                     Czechia    NaN              18           6.9198
# 25    Taiwan Province of China    NaN              26           6.5125
# 38                  Guatemala*    NaN              39           6.2622
# 49                     Kuwait*    NaN              50           6.1061
# 64                    Belarus*    NaN              65           5.8215
# 77               Turkmenistan*    NaN              78           5.4743
# 78               North Cyprus*    NaN              79           5.4666
# 80   Hong Kong S.A.R. of China    NaN              81           5.4248
# 85                      Libya*    NaN              86           5.3302
# 88             North Macedonia    NaN              89           5.1990
# 91                 Azerbaijan*    NaN              92           5.1734
# ...

# %%
df2022.shape
df2022.to_csv('2022.csv', index=False )

# %%
df2022['Region'].unique()
# Out:
# array(['Western Europe', nan, 'Middle East and Northern Africa',
#        'Australia and New Zealand', 'North America',
#        'Central and Eastern Europe', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Sub-Saharan Africa', 'Eastern Asia',
#        'Southern Asia'], dtype=object)

# %%
df2022 = pd.read_csv('2022_cleaned.csv')
df2022
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Finland                   Western Europe               1
# 1        Denmark                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3    Switzerland                   Western Europe               4
# 4    Netherlands                   Western Europe               5
# ..           ...                              ...             ...
# 141    Botswana*               Sub-Saharan Africa             142
# 142      Rwanda*               Sub-Saharan Africa             143
# 143     Zimbabwe               Sub-Saharan Africa             144
# 144      Lebanon  Middle East and Northern Africa             145
# 145  Afghanistan                    Southern Asia             146
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0             7.8210                  1.891628  1.258108
# ...

# %%
# Perform the merge, specifying 'suffixes' to avoid duplicate columns
df2023 = pd.merge(df2023, df2022[['Country', 'Region']], on='Country', how='left', suffixes=('_df2023', '_df2022'))

# Fill missing values in the 'Region_df2023' column with values from 'Region_df2022'
df2023['Region_df2023'] = df2023['Region_df2023'].fillna(df2023['Region_df2022'])

# Drop the additional 'Region_df2022' column if needed
df2023.drop(columns=['Region_df2022'], inplace=True)

# Rename the remaining 'Region_df2023' column to 'Region'
df2023.rename(columns={'Region_df2023': 'Region'}, inplace=True)

# %%
df2023[df2023.isna().any(axis=1)]
# Out:
#                 Country Region  Happiness Rank  Happiness Score  \
# 98   State of Palestine    NaN              99           4.9078
# 105             Turkiye    NaN             106           4.6135
# 118              Gambia    NaN             119           4.2794
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 98                   1.143960  1.308868                       NaN  0.416328
# 105                  1.714366  1.147928                  0.466803  0.124665
# 118                  0.760724  0.613659                  0.173556  0.285875
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 98                        0.066824    0.065409                NaN
# 105                       0.096117    0.095108           0.968547
# 118                       0.033252    0.331844           2.080531

# %%
# Dictionary mapping countries to regions based on available data
region_mapping = {
    'State of Palestine': 'Middle East and Northern Africa',
    'Turkiye': 'Middle East and Northern Africa',
    'Gambia': 'Sub-Saharan Africa',
    # Add more countries and their corresponding regions as needed
}

# Fill missing 'Region' values based on the dictionary mapping
df2023['Region'] = df2023['Region'].fillna(df2023['Country'].map(region_mapping))

# %%
df2023[df2023.isna().any(axis=1)]
# Out:
#                Country                           Region  Happiness Rank  \
# 98  State of Palestine  Middle East and Northern Africa              99
#
#     Happiness Score  Economy (GDP per Capita)    Family  \
# 98           4.9078                   1.14396  1.308868
#
#     Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 98                       NaN  0.416328                       0.066824
#
#     Generosity  Dystopia Residual
# 98    0.065409                NaN

# %%
df2023.dropna(inplace=True)

# %%
df2023[df2023.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df2023.to_csv('2023_cleaned.csv', index=False)

# %%
df2021[df2021.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption), Dystopia + residual]
# Index: []

# %%
df2021.to_csv('2021_cleaned.csv', index=False)

# %%
df2020[df2020.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption), Dystopia + residual]
# Index: []

# %%
df2020.to_csv('2020_cleaned.csv', index=False)

# %%
df2019[df2019.isna().any(axis=1)]
# Out:
#                        Country Region  Happiness Rank  Happiness Score  \
# 24    Taiwan Province of China    NaN              25           6.4462
# 75   Hong Kong S.A.R. of China    NaN              76           5.4304
# 119                     Gambia    NaN             120           4.5163
# 122                 Mozambique    NaN             123           4.4662
# 134                  Swaziland    NaN             135           4.2116
# 143                    Lesotho    NaN             144           3.8019
# 154   Central African Republic    NaN             155           3.0830
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 24                   1.368087  1.430416                  0.913703  0.350553
# 75                   1.437999  1.276593                  1.122140  0.439628
# 119                  0.307813  0.939059                  0.427996  0.382251
# 122                  0.203645  0.985662                  0.390127  0.493750
# ...

# %%
# Perform the merge, specifying 'suffixes' to avoid duplicate columns
df2019 = pd.merge(df2019, df2022[['Country', 'Region']], on='Country', how='left', suffixes=('_df2023', '_df2022'))

# Fill missing values in the 'Region_df2023' column with values from 'Region_df2022'
df2019['Region_df2023'] = df2019['Region_df2023'].fillna(df2019['Region_df2022'])

# Drop the additional 'Region_df2022' column if needed
df2019.drop(columns=['Region_df2022'], inplace=True)

# Rename the remaining 'Region_df2023' column to 'Region'
df2019.rename(columns={'Region_df2023': 'Region'}, inplace=True)
df2019
# Out:
#                       Country              Region  Happiness Rank  \
# 0                     Finland      Western Europe               1
# 1                     Denmark      Western Europe               2
# 2                      Norway      Western Europe               3
# 3                     Iceland      Western Europe               4
# 4                 Netherlands      Western Europe               5
# ..                        ...                 ...             ...
# 151                    Rwanda  Sub-Saharan Africa             152
# 152                  Tanzania  Sub-Saharan Africa             153
# 153               Afghanistan       Southern Asia             154
# 154  Central African Republic                 NaN             155
# 155               South Sudan  Sub-Saharan Africa             156
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0             7.7689                  1.340243  1.587276
# ...

# %%
# Dictionary mapping countries to regions based on available data
region_mapping = {
    'State of Palestine': 'Middle East and Northern Africa',
    'Turkiye': 'Middle East and Northern Africa',
    'Gambia': 'Sub-Saharan Africa',
    'Swaziland': 'Sub-Saharan Africa',
    'Lesotho': 'Sub-Saharan Africa',
    'Central African Republic': 'Sub-Saharan Africa'
    # Add more countries and their corresponding regions as needed
}

# Fill missing 'Region' values based on the dictionary mapping
df2019['Region'] = df2019['Region'].fillna(df2019['Country'].map(region_mapping))
df2019[df2019.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df2019.to_csv('2019_cleaned.csv', index=False)

# %%
df2018[df2018.isna().any(axis=1)]
# Out:
#                       Country Region  Happiness Rank  Happiness Score  \
# 25   Taiwan Province of China    NaN              26           6.4406
# 37          Trinidad & Tobago    NaN              38           6.1919
# 57            Northern Cyprus    NaN              58           5.8348
# 75       Hong Kong SAR, China    NaN              76           5.4304
# 122                Mozambique    NaN             123           4.4166
# 140                   Lesotho    NaN             141           3.8082
# 154  Central African Republic    NaN             155           3.0830
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 25                   1.365053  1.435968                  0.857375  0.417559
# 37                   1.222706  1.492152                  0.563752  0.575081
# 57                   1.228816  1.211011                  0.909132  0.494897
# 75                   1.405062  1.289982                  1.029650  0.524217
# ...

# %%
# Perform the merge, specifying 'suffixes' to avoid duplicate columns
df2018 = pd.merge(df2018, df2019[['Country', 'Region']], on='Country', how='left', suffixes=('_df2023', '_df2022'))

# Fill missing values in the 'Region_df2023' column with values from 'Region_df2022'
df2018['Region_df2023'] = df2018['Region_df2023'].fillna(df2018['Region_df2022'])

# Drop the additional 'Region_df2022' column if needed
df2018.drop(columns=['Region_df2022'], inplace=True)

# Rename the remaining 'Region_df2023' column to 'Region'
df2018.rename(columns={'Region_df2023': 'Region'}, inplace=True)

df2018[df2018.isna().any(axis=1)]
# Out:
#                  Country Region  Happiness Rank  Happiness Score  \
# 37     Trinidad & Tobago    NaN              38           6.1919
# 57       Northern Cyprus    NaN              58           5.8348
# 75  Hong Kong SAR, China    NaN              76           5.4304
#
#     Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 37                  1.222706  1.492152                  0.563752  0.575081
# 57                  1.228816  1.211011                  0.909132  0.494897
# 75                  1.405062  1.289982                  1.029650  0.524217
#
#     Trust (Government Corruption)  Generosity  Dystopia Residual
# 37                       0.018647    0.171070           2.148453
# 57                       0.153539    0.178681           1.658751
# 75                       0.291431    0.246465           0.643622

# %%
# Add missing countries and their corresponding regions to the dictionary
region_mapping.update({
    'Trinidad & Tobago': 'Latin America and Caribbean',
    'Northern Cyprus': 'Middle East and Northern Africa',
    'Hong Kong SAR, China': 'Eastern Asia'
})

# Fill missing 'Region' values based on the updated dictionary mapping
df2018['Region'] = df2018['Region'].fillna(df2018['Country'].map(region_mapping))

# %%
df2018.to_csv('2018_cleaned.csv', index=False)

# %%
df2017[df2017.isna().any(axis=1)]
# Out:
#                       Country Region  Happiness Rank  Happiness Score  \
# 32   Taiwan Province of China    NaN              33            6.422
# 70    Hong Kong S.A.R., China    NaN              71            5.472
# 112                Mozambique    NaN             113            4.550
# 138                   Lesotho    NaN             139            3.808
# 154  Central African Republic    NaN             155            2.693
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 32                   1.433627  1.384565                  0.793984  0.361467
# 70                   1.551675  1.262791                  0.943062  0.490969
# 112                  0.234306  0.870701                  0.106654  0.480791
# 138                  0.521021  1.190095                  0.000000  0.390661
# 154                  0.000000  0.000000                  0.018773  0.270842
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
# Perform the merge, specifying 'suffixes' to avoid duplicate columns
df2017 = pd.merge(df2017, df2018[['Country', 'Region']], on='Country', how='left', suffixes=('_df2023', '_df2022'))

# Fill missing values in the 'Region_df2023' column with values from 'Region_df2022'
df2017['Region_df2023'] = df2017['Region_df2023'].fillna(df2017['Region_df2022'])

# Drop the additional 'Region_df2022' column if needed
df2017.drop(columns=['Region_df2022'], inplace=True)

# Rename the remaining 'Region_df2023' column to 'Region'
df2017.rename(columns={'Region_df2023': 'Region'}, inplace=True)

df2017[df2017.isna().any(axis=1)]
# Out:
#                     Country Region  Happiness Rank  Happiness Score  \
# 70  Hong Kong S.A.R., China    NaN              71            5.472
#
#     Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 70                  1.551675  1.262791                  0.943062  0.490969
#
#     Trust (Government Corruption)  Generosity  Dystopia Residual
# 70                       0.293934    0.374466           0.554633

# %%
region_mapping.update({
    'Hong Kong S.A.R., China': 'Eastern Asia'
})

# Fill missing 'Region' values based on the updated dictionary mapping
df2017['Region'] = df2017['Region'].fillna(df2017['Country'].map(region_mapping))

# %%
df2017[df2017.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df2017.to_csv('df2017_cleaned.csv', index='False')

# %%
df2016[df2016.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df2016.to_csv('2016_cleaned.csv', index=False)

# %%
df2015[df2015.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df2015.to_csv('2015_cleaned.csv', index=False)

# %%
import plotly.express as px

# %%
# start on visualisations

def create_choropleth(dataset):
    fig = px.choropleth(dataset, 
                    locations="Country", 
                    locationmode='country names',
                    color="Happiness Score",  # Color represents Happiness Score
                    hover_name="Country", 
                    # animation_frame="Year",  # Year is the column representing the years in your dataset
                    color_continuous_scale=px.colors.sequential.Plasma,  # Choose the color scale
                    projection="natural earth")  # Choose the map projection style

    # Set the layout title and show the figure
    fig.update_layout(title_text='World Happiness Index (2015-2023)',
                    geo=dict(showcoastlines=True, coastlinecolor="Black", showland=True, landcolor="white",
                            showframe=False, projection_type="mercator"))

    # Show the animation
    fig.show()

# %%
create_choropleth(df2015)

# %%
# %pip install --upgrade plotly
# Out:
# ...
#      |████████████████████████████████| 15.6 MB 2.3 MB/s eta 0:00:01
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.17.0
#     Uninstalling plotly-5.17.0:
#       Successfully uninstalled plotly-5.17.0
# ...
# Note: you may need to restart the kernel to use updated packages.
